# %%
from loaddata import DATA, DATAS, FitData

# %% [markdown]
# # DATA

# %%
data_object = DATA('DATA/NiPS3_100nm_1/exp1_953Hz_10mA_1st.csv')
data_object.plot_V_theta()
data_object.plot_V_theta_all(cmap=None)

# %% [markdown]
# # FitDATA

# %%
function_object = FitData(data_object)
function_object.optimize()
function_object.plot()
data_object.plot_V_theta()

# %% [markdown]
# # DATAS

# %%
sample = DATAS('DATA/NiPS3_100nm_5_2/')
sample.select_data(field=3,current=5,expID=2)
sample.plot_data('temp', range = (10,200))

# %%
sample_4_1 = DATAS('DATA/NiPS3_100nm_4_1')
sample_4_1.select_data(temp=20,current=5)
sample_4_1.plot_data('field', range=(1,5), cmap='cool')
