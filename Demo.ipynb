# %%
from loaddata import *

# %% [markdown]
# # DATA

# %%
data_object = DATA('DATA/NiPS3_100nm_1/exp1_953Hz_10mA_1st.csv') #object

# %%
data_object.plot_V_theta_all(cmap=None) #method

# %%
data_object.plot_V_theta()
data_object.plot_V_theta_all(cmap=None)

# %% [markdown]
# # FitDATA

# %%
function_object = FitData(data_object)

# %%
function_object.fitting_type
# Out:
# '1st'

# %%
function_object.model
# Out:
# FirstHarmonicFun()

# %%
data_object.plot_V_theta()
function_object.plot()

# %%
function_object.optimize(verbose=True)
# Out:
# step 0, loss: 0.58685374
# step 100, loss: 0.21144713
# step 200, loss: 0.20737505
# step 300, loss: 0.20737499
# step 400, loss: 0.20737499
# step 500, loss: 0.20737499
# step 600, loss: 0.20737500
# step 700, loss: 0.20737500
# step 800, loss: 0.20737499
# step 900, loss: 0.20737500
# step 999, loss: 0.20737499

# %%
function_object.plot()
data_object.plot_V_theta()

# %% [markdown]
# # DATAS

# %%
sample = DATAS('DATA/NiPS3_100nm_5_2/')

# %%
print(sample.fns)
print('file count: ',len(sample.fns),' files')
# Out:
# ['DATA/NiPS3_100nm_5_2/exp2_140K_3T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp2_60K_3T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp2_80K_3T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp1_20K_3T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp2_120K_3T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp2_10K_3T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp2_200K_3T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp2_20K_3T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp2_100K_3T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp2_160K_3T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp2_40K_3T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp3_20K_5T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp1_20K_3T_5mA_ZFC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp1_20K_3T_5mA_FC_ZCC.csv', 'DATA/NiPS3_100nm_5_2/exp2_180K_3T_5mA_FC_CC.csv']
# file count:  15  files

# %%
sample.select_data(field=3,current=5,expID=2)

# %%
print(sample.fns)
print('file count: ',len(sample.fns),' files')
# Out:
# ['DATA/NiPS3_100nm_5_2/exp2_140K_3T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp2_60K_3T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp2_80K_3T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp2_120K_3T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp2_10K_3T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp2_200K_3T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp2_20K_3T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp2_100K_3T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp2_160K_3T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp2_40K_3T_5mA_FC_CC.csv', 'DATA/NiPS3_100nm_5_2/exp2_180K_3T_5mA_FC_CC.csv']
# file count:  11  files

# %%
sample.plot_temp()

# %% [markdown]
# # A * sin 2(x - b) + c
# # A' * | cos 2(x - b) * cos (x-b) +c' |
#
# # $\frac{A'}{A} = \frac{H_{FL}}{H_{ext}}$
